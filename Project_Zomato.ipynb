# %% [markdown]
# ## Zomato Dataset Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the Data With the Help of Pandas

df = pd.read_csv('zomato.csv', encoding = 'latin-1')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# These are my int Features and their descriptive statisics
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
# To check my Columns and the Datatypes of each Feature
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#To Check the Null Value or Missing Value in the Dataset
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# To check the null values with the help of heatmap.
sns.heatmap(df.isnull() , yticklabels = False , cbar = False , cmap ='coolwarm')
# Out:
# <Axes: >

# %%
df_country = pd.read_excel('Country-Code.xlsx')

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df_country.shape
# Out:
# (15, 2)

# %%
#To check The datatypes of the the Country
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
# To Check the null or Missing Values
df_country.isnull().sum()
# Out:
# Country Code    0
# Country         0
# dtype: int64

# %% [markdown]
# There is No null value in the dataset

# %% [markdown]
# In Both Dataset i have the country code so i Will Merge Both Of Them. ( df & df_country )

# %%
# This is my final record by merging both of the datasets
Final_df = pd.merge(df , df_country , how = 'outer' , on ='Country Code')

# %%
Final_df.head()
# Out:
#    Restaurant ID                        Restaurant Name  Country Code  City  \
# 0        3400025                             Jahanpanah             1  Agra
# 1        3400341                    Rangrezz Restaurant             1  Agra
# 2        3400005                Time2Eat - Mama Chicken             1  Agra
# 3        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 4        3400017                         Pinch Of Spice             1  Agra
#
#                                              Address     Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#     Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
Final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Country_No = Final_df['Country'].value_counts().values

# %%
Country_Name = Final_df['Country'].value_counts().index

# %%
# Top Countries Using Zomato
plt.pie(Country_No[:3] , labels = Country_Name[:3]  , autopct = '%1.2f%%'  )
# Out:
# ([<matplotlib.patches.Wedge at 0x20525134230>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# Observations - It is Observed that Approximately 95% users of Zomato are from india Followed by United States and United Kingdom

# %%
Ratings = Final_df.groupby(['Aggregate rating' , 'Rating color', 'Rating text']).size().reset_index().rename(columns = {0:'Total_Restaurant'})

# %%
Ratings
# Out:
#     Aggregate rating Rating color Rating text  Total_Restaurant
# 0                0.0        White   Not rated              2148
# 1                1.8          Red        Poor                 1
# 2                1.9          Red        Poor                 2
# 3                2.0          Red        Poor                 7
# 4                2.1          Red        Poor                15
# 5                2.2          Red        Poor                27
# 6                2.3          Red        Poor                47
# 7                2.4          Red        Poor                87
# 8                2.5       Orange     Average               110
# 9                2.6       Orange     Average               191
# 10               2.7       Orange     Average               250
# 11               2.8       Orange     Average               315
# 12               2.9       Orange     Average               381
# 13               3.0       Orange     Average               468
# ...

# %% [markdown]
# Observations -
# 2148 No of Peoples didnot Rated the Zomato
#
# When Rating is Between (1.8 - 2.4) ---------->Poor
#
# When Rating is Between (2.5 - 3.4) ---------->Average
#
# When Rating is Between (3.5 - 3.9) ---------->Good
#
# When Rating is Between (4.0 - 4.4) ---------->Very Good
#
# When Rating is Between (4.4 - 4.9) ---------->Excellent

# %%
sns.barplot(x = 'Aggregate rating' , y = 'Total_Restaurant' , data = Ratings , hue = 'Rating color' , palette = ['White' , 'Red' , 'Orange' , 'Yellow' , 'Green' , 'Green'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Total_Restaurant'>

# %% [markdown]
# Observations =
#
# 1 - Count of not rated is very high
#
# 2 - Maximum No of peoples are rated between 2.5 to 3.5

# %%
sns.countplot(x = 'Rating color' , hue = 'Rating color' , palette = ['Blue' , 'Red' , 'Orange' , 'Yellow' , 'Green' , 'Green'] , data = Ratings)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# Observations - Orange Rating has Maximum no of frequency in the Data which States that the Maximum number of peoples giving between [2.5 to 3.5]

# %%
Final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Final_df.groupby(['Aggregate rating' , 'Country']).size()
# Out:
# Aggregate rating  Country
# 0.0               Brazil               5
#                   India             2139
#                   United Kingdom       1
#                   United States        3
# 1.8               India                1
#                                     ...
# 4.9               Sri Lanka            1
#                   Turkey               3
#                   UAE                  4
#                   United Kingdom       4
#                   United States       14
# Length: 222, dtype: int64

# %%
Final_df[Final_df['Aggregate rating'] == 0.0].groupby('Country').size().reset_index().rename(columns = {0:'Total_Country'})
# Out:
#           Country  Total_Country
# 0          Brazil              5
# 1           India           2139
# 2  United Kingdom              1
# 3   United States              3

# %% [markdown]
# Observations -
#
# 2139 Peoples from India Which Gave 0 Rating
#
# 5    Peoples from Brazil Which Gave 0 Rating
#
# 1    Peoples from UK Which Gave 0 Rating
#
# 3    Peoples from US Which Gave 0 Rating

# %%
# Finding which currency is used by which country..?

# %%
Final_df.groupby(['Currency','Country']).size().reset_index().rename(columns = {0: 'Total_Countries'})
# Out:
#                   Currency         Country  Total_Countries
# 0         Botswana Pula(P)     Phillipines               22
# 1       Brazilian Real(R$)          Brazil               60
# 2                Dollar($)       Australia               24
# 3                Dollar($)          Canada                4
# 4                Dollar($)       Singapore               20
# 5                Dollar($)   United States              434
# 6       Emirati Diram(AED)             UAE               60
# 7       Indian Rupees(Rs.)           India             8652
# 8   Indonesian Rupiah(IDR)       Indonesia               21
# 9            NewZealand($)     New Zealand               40
# 10              Pounds(£)  United Kingdom               80
# 11         Qatari Rial(QR)           Qatar               20
# 12                 Rand(R)    South Africa               60
# 13   Sri Lankan Rupee(LKR)       Sri Lanka               20
# 14        Turkish Lira(TL)          Turkey               34

# %%
Final_df[Final_df['Has Online delivery'] == 'Yes'].groupby('Country').size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %% [markdown]
# Observations -  Only India and UAE Countries having Online Delivery

# %%
city_values = Final_df.City.value_counts().values
city_labels = Final_df.City.value_counts().index

plt.pie(city_values[:5], labels=city_labels[:5])
# Out:
# ([<matplotlib.patches.Wedge at 0x205261b21e0>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')])
